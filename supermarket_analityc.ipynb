# %%
import numpy as np
import pandas as pd
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
data=pd.read_csv('./pregunta 1/supermarket_sales - Sheet1.csv')
data.sort_values(by='City')
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 750  210-30-7976      B   Mandalay        Member  Female
# 570  834-83-1826      B   Mandalay        Member  Female
# 285  498-41-1961      B   Mandalay        Normal    Male
# 901  509-10-0516      B   Mandalay        Normal    Male
# 571  343-61-3544      B   Mandalay        Member    Male
# 573  355-34-6244      B   Mandalay        Normal    Male
# 575  339-96-8318      B   Mandalay        Member    Male
# 576  458-61-0011      B   Mandalay        Normal    Male
# 579  207-73-1363      B   Mandalay        Normal    Male
# 804  831-81-6575      B   Mandalay        Member  Female
# 288  283-79-9594      B   Mandalay        Normal  Female
# 275  566-19-5475      B   Mandalay        Normal    Male
# 907  851-98-3555      B   Mandalay        Normal  Female
# 583  359-90-3665      B   Mandalay        Member  Female
# 270  783-09-1637      B   Mandalay        Normal  Female
# ...

# %%
len(data[data['City']=='Mandalay'])
#print(tamanio)
# Out:
# 332
